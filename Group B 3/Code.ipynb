# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv("airquality.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2     High
# 2             3   12.0    149.0  12.6    74      5    3   Medium
# 3             4   18.0    313.0  11.5    62      5    4   Medium
# 4             5    NaN      NaN  14.3    56      5    5      NaN
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      Low
# 149         150    NaN    145.0  13.2    77      9   27      Low
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29     High
# 152         153   20.0    223.0  11.5    68      9   30   Medium
#
# [153 rows x 8 columns]

# %%
data=data.drop("Unnamed: 0",axis=1)
data
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0     41.0    190.0   7.4    67      5    1     High
# 1     36.0    118.0   8.0    72      5    2     High
# 2     12.0    149.0  12.6    74      5    3   Medium
# 3     18.0    313.0  11.5    62      5    4   Medium
# 4      NaN      NaN  14.3    56      5    5      NaN
# ..     ...      ...   ...   ...    ...  ...      ...
# 148   30.0    193.0   6.9    70      9   26      Low
# 149    NaN    145.0  13.2    77      9   27      Low
# 150   14.0    191.0  14.3    75      9   28     High
# 151   18.0    131.0   8.0    76      9   29     High
# 152   20.0    223.0  11.5    68      9   30   Medium
#
# [153 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Ozone       37
# Solar.R      7
# Wind         0
# Temp         0
# Month        0
# Day          0
# Humidity     6
# dtype: int64

# %%
data["Ozone"].fillna(data["Ozone"].mean(),inplace=True)
data["Solar.R"].fillna(data["Solar.R"].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    6
# dtype: int64

# %%
plt.pie([data["Ozone"].mean(),data["Solar.R"].mean(),data["Wind"].mean(),data["Temp"].mean()],
        autopct="%1.0f%%",explode=[0.02,0.02,0.02,0.02],labels=["Ozone","Solar.R","Wind","Temp"])
plt.plot()
# Out:
# []

# %%
plt.scatter(data["Temp"],data["Day"],color="red")

# %%
plt.plot(data.iloc[0:25, 5], data.iloc[0:25, 3], color="purple")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Temperature VS Day")
# Out:
# Text(0.5, 1.0, 'Temperature VS Day')

# %%
y = np.arange(len(data.iloc[0:25, 3]))

for i in range(len(data.iloc[0:25,3])):
    plt.text(i,data.iloc[0:25,3][i],data.iloc[0:25,3][i],ha='center')

plt.bar(x=y, height=data.iloc[0:25, 3], tick_label=y,width=0.5, color="dodgerblue")
plt.title("Temeprature vs Days Graph")
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.show()

# %%
plt.boxplot(x=data[["Ozone","Solar.R","Wind","Temp"]],labels=["Ozone","Solar.R","Wind","Temp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x206a6fb3ed0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x206a6ff8590>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x206a6fdb6d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x206a6ff9690>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x206a6fe7f90>,
# ...
#  'means': []}

# %%
plt.hist(x=data["Temp"],bins=20)
plt.title("Temeprature")
plt.xlabel("Level")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
print(data.columns)
sb.pairplot(data.iloc[:,[0,1,2,3,6]],hue="Humidity")
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day', 'Humidity'], dtype='object')

# %%
sb.heatmap(data.iloc[:,[0,1,2]])
# Out:
# <Axes: >

# %%
from wordcloud import WordCloud,STOPWORDS
from lorem_text import lorem

# The term “stop word” refers to the most common words in a language

stopwords=set(STOPWORDS)
text=lorem.paragraph()
print(text)
wordCloud=WordCloud(width=800,height=800,background_color="white",min_font_size=10,stopwords=stopwords).generate(text)
plt.imshow(wordCloud)
plt.axis('off')
plt.tight_layout(pad=0)
# Out:
# Maxime nulla soluta eaque quisquam praesentium, error dolores odio illum totam quis rerum, nostrum vel tempora iusto fugit corporis maxime debitis tenetur iste sapiente nemo? Numquam praesentium aperiam earum eligendi magnam quaerat distinctio officia assumenda fugit, fugit mollitia iure excepturi?
