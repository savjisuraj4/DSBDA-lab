# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Facebook.csv")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.shape
# Out:
# (500, 19)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
subset1=data.iloc[:,:8]
subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach
# ...

# %%
subset1.shape
# Out:
# (500, 8)

# %%
subset2=data.loc[0:199]
subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 195            133594   Photo         2           8             6         10
# 196            133594   Photo         1           8             6          8
# 197            133594   Photo         2           8             5         13
# 198            133451   Photo         1           8             4          9
# 199            132817   Photo         3           8             4         10
#
# ...

# %%
subset2.shape
# Out:
# (200, 19)

# %%
subset3=data[["Post Month","Post Weekday","Post Hour"]]
subset3
# Out:
#      Post Month  Post Weekday  Post Hour
# 0            12             4          3
# 1            12             3         10
# 2            12             3          3
# 3            12             2         10
# 4            12             2          3
# ..          ...           ...        ...
# 495           1             7          2
# 496           1             5          8
# 497           1             5          2
# 498           1             4         11
# 499           1             4          4
#
# [500 rows x 3 columns]

# %%
subset3.shape
# Out:
# (500, 3)

# %%
subset4=data.iloc[:,7:14]
subset4
# Out:
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                         2752                             5091
# 1                        10460                            19057
# 2                         2413                             4373
# 3                        50128                            87991
# 4                         7244                            13594
# ..                         ...                              ...
# 495                       4684                             7536
# 496                       3480                             6229
# 497                       3778                             7216
# 498                       4156                             7564
# 499                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# ...

# %%
subset4.shape
# Out:
# (500, 7)

# %%
subset5=data.loc[:,['Lifetime Post Total Reach','Lifetime Post Total Impressions']]
subset5
# Out:
#      Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0                         2752                             5091
# 1                        10460                            19057
# 2                         2413                             4373
# 3                        50128                            87991
# 4                         7244                            13594
# ..                         ...                              ...
# 495                       4684                             7536
# 496                       3480                             6229
# 497                       3778                             7216
# 498                       4156                             7564
# 499                       4188                             7292
#
# [500 rows x 2 columns]

# %%
subset5.shape
# Out:
# (500, 2)

# %%
print(subset1.shape)
print(subset5.shape)

merge1=subset1.merge(subset5)
merge1
# Out:
# (500, 8)
# (500, 2)
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 525             85093   Photo         3           1             7          2
# 526             81370   Photo         2           1             5          8
# 527             81370   Photo         1           1             5          2
# 528             81370   Photo         3           1             4         11
# 529             81370   Photo         2           1             4          4
#
# ...

# %%
merge1.shape
# Out:
# (530, 9)

# %%
print(subset3.columns)
print(subset4.columns)
merge2=pd.concat([subset3,subset4])
merge2
# Out:
# Index(['Post Month', 'Post Weekday', 'Post Hour'], dtype='object')
# Index(['Lifetime Post Total Reach', 'Lifetime Post Total Impressions',
#        'Lifetime Engaged Users', 'Lifetime Post Consumers',
#        'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page'],
#       dtype='object')
#      Post Month  Post Weekday  Post Hour  Lifetime Post Total Reach  \
# 0          12.0           4.0        3.0                        NaN
# 1          12.0           3.0       10.0                        NaN
# 2          12.0           3.0        3.0                        NaN
# 3          12.0           2.0       10.0                        NaN
# 4          12.0           2.0        3.0                        NaN
# ..          ...           ...        ...                        ...
# 495         NaN           NaN        NaN                     4684.0
# ...

# %%
merge2.shape
# Out:
# (1000, 10)

# %%
transpose=data.transpose()
transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
transpose.shape
# Out:
# (19, 500)

# %%
sort_values=data.sort_values(by="Post Month")
sort_values
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 475             86909   Photo         3           1             6         16
# 476             86909   Photo         1           1             6         10
# 477             86909    Link         1           1             6          4
# 478             86909   Photo         3           1             5         13
# ..                ...     ...       ...         ...           ...        ...
# 29             138895   Video         1          12             4         11
# 28             138895   Photo         2          12             5          3
# 27             138458   Photo         3          12             5          3
# 38             138895  Status         2          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
sort_values.shape
# Out:
# (500, 19)

# %%
# Pandas melt() function is used to change the DataFrame format from wide to long

reshape=data.melt(id_vars=["Type","Category"],value_vars=["Post Month","Post Weekday"])
reshape
# Out:
#        Type  Category      variable  value
# 0     Photo         2    Post Month     12
# 1    Status         2    Post Month     12
# 2     Photo         3    Post Month     12
# 3     Photo         2    Post Month     12
# 4     Photo         2    Post Month     12
# ..      ...       ...           ...    ...
# 995   Photo         3  Post Weekday      7
# 996   Photo         2  Post Weekday      5
# 997   Photo         1  Post Weekday      5
# 998   Photo         3  Post Weekday      4
# 999   Photo         2  Post Weekday      4
#
# [1000 rows x 4 columns]

# %%
reshape.shape
# Out:
# (1000, 4)
